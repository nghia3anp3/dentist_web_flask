# %%
import pandas as pd

data = [
    (1, '2023-12-02', '397', 'Phan Nguyên Phương', 'T001      ', 'Paracetamol                   ', 5, 10000, 'D001      ', 'Cạo vôi răng', 1, 100000, 2170000),
    (1, '2023-12-02', '397', 'Phan Nguyên Phương', 'T002      ', 'Panadol                       ', 10, 2000, 'D001      ', 'Cạo vôi răng', 1, 100000, 2170000),
    (1, '2023-12-02', '397', 'Phan Nguyên Phương', 'T001      ', 'Paracetamol                   ', 5, 10000, 'D002      ', 'Nhổ răng', 1, 2000000, 2170000),
    (1, '2023-12-02', '397', 'Phan Nguyên Phương', 'T002      ', 'Panadol                       ', 10, 2000, 'D002      ', 'Nhổ răng', 1, 2000000, 2170000),
    (2, '2023-14-02', '398', 'Phan Nguyên Phươngggg', 'T089      ', 'Pacama                       ', 100, 200, 'D0021      ', 'Nhổ răng', 2, 20000200, 21700400)
]

columns = ['Col1', 'Col2', 'Col3', 'Col4', 'Col5', 'Col6', 'Col7', 'Col8', 'Col9', 'Col10', 'Col11', 'Col12', 'Col13']

df = pd.DataFrame(data, columns=columns)
df
# Out:
#    Col1        Col2 Col3                   Col4        Col5  \
# 0     1  2023-12-02  397     Phan Nguyên Phương  T001
# 1     1  2023-12-02  397     Phan Nguyên Phương  T002
# 2     1  2023-12-02  397     Phan Nguyên Phương  T001
# 3     1  2023-12-02  397     Phan Nguyên Phương  T002
# 4     2  2023-14-02  398  Phan Nguyên Phươngggg  T089
#
#                              Col6  Col7   Col8         Col9         Col10  \
# 0  Paracetamol                        5  10000   D001        Cạo vôi răng
# 1  Panadol                           10   2000   D001        Cạo vôi răng
# 2  Paracetamol                        5  10000   D002            Nhổ răng
# 3  Panadol                           10   2000   D002            Nhổ răng
# 4   Pacama                          100    200  D0021            Nhổ răng
#
#    Col11     Col12     Col13
# 0      1    100000   2170000
# 1      1    100000   2170000
# 2      1   2000000   2170000
# 3      1   2000000   2170000
# 4      2  20000200  21700400

# %%
df.drop_duplicates ()
# Out:
#    Col1        Col2 Col3                   Col4        Col5  \
# 0     1  2023-12-02  397     Phan Nguyên Phương  T001
# 1     1  2023-12-02  397     Phan Nguyên Phương  T002
# 2     1  2023-12-02  397     Phan Nguyên Phương  T001
# 3     1  2023-12-02  397     Phan Nguyên Phương  T002
# 4     2  2023-14-02  398  Phan Nguyên Phươngggg  T089
#
#                              Col6  Col7   Col8         Col9         Col10  \
# 0  Paracetamol                        5  10000   D001        Cạo vôi răng
# 1  Panadol                           10   2000   D001        Cạo vôi răng
# 2  Paracetamol                        5  10000   D002            Nhổ răng
# 3  Panadol                           10   2000   D002            Nhổ răng
# 4   Pacama                          100    200  D0021            Nhổ răng
#
#    Col11     Col12     Col13
# 0      1    100000   2170000
# 1      1    100000   2170000
# 2      1   2000000   2170000
# 3      1   2000000   2170000
# 4      2  20000200  21700400

# %%
df.groupby (by= "Col1").head()
# Out:
#    Col1        Col2 Col3                   Col4        Col5  \
# 0     1  2023-12-02  397     Phan Nguyên Phương  T001
# 1     1  2023-12-02  397     Phan Nguyên Phương  T002
# 2     1  2023-12-02  397     Phan Nguyên Phương  T001
# 3     1  2023-12-02  397     Phan Nguyên Phương  T002
# 4     2  2023-14-02  398  Phan Nguyên Phươngggg  T089
#
#                              Col6  Col7   Col8         Col9         Col10  \
# 0  Paracetamol                        5  10000   D001        Cạo vôi răng
# 1  Panadol                           10   2000   D001        Cạo vôi răng
# 2  Paracetamol                        5  10000   D002            Nhổ răng
# 3  Panadol                           10   2000   D002            Nhổ răng
# 4   Pacama                          100    200  D0021            Nhổ răng
#
#    Col11     Col12     Col13
# 0      1    100000   2170000
# 1      1    100000   2170000
# 2      1   2000000   2170000
# 3      1   2000000   2170000
# 4      2  20000200  21700400

# %%
a = (False,)
a.value()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 a = (False,)
# ----> 2 a.value()
#
# AttributeError: 'tuple' object has no attribute 'value'
